# %%
num1=int(input("enter any number bro"))
num2=int(input("enter any number bro"))
num3=num1+num2
num4=num1-num2
num5=num1*num2
num6=num1/num2
print("bro add", num3)
print("bro mul", num5)
print("bro div", num6)
print("bro sub", num4)
# Out:
# bro add 2
# bro mul 1
# bro div 1.0
# bro sub 0

# %%
a=1
b=1
c=a+b
print(a+b)
print(type(a))
# Out:
# 2
# <class 'int'>

# %%
print(f"difference of {num1} and {num2} is {num4}")
# Out:
# difference of 1 and 1 is 0

# %%
num1=int(input("enter any number bro"))
num2=int(input("enter any number bro"))
if num1>num2:
    print(f"{num1} is greater than {num2}")
elif num1==num2:
        print(f"{num1} and {num2} are equal")
else: 
 print(f"{num2} is greater than {num1 }")
# Out:
# 2 and 2 are equal

# %%
print(max(num1,num2))
# Out:
# 2

# %%
a=int(input("enter yout number"))
if(a%2)==0:
 print(f"{a} is even")
else:
 print(f" {a} is odd")
# Out:
#  3 is odd

# %%
num1=int(input("Enter your numbers"))
num2=int(input("Enter your numbers"))
num3=int(input("Enter your numbers"))
num4=int(input("Enter your numbers"))
if num1>num2 and num1>num3 and num1>num4:
    print(f"{num1} is the greatest number")
elif num2>num1 and num2>num3 and num2>num4:
    print(f"{num2} is the greatest number")
elif num3>num1 and num3>num2 and num3>num4:
    print(f"{num3} is the greatest number")
else:  
     print(f"{num4} is the greatest number")
# Out:
# 9 is the greatest number

# %%
marks=float(input("Input your grades and keep it for real"))
if marks>=80:
    print("Distinsion")
elif marks >=70:
    print("First division")
elif marks>=60:
    print("Second division")
elif marks>=50:
    print("third division")
else:
    print("padai likhai karo, iaswias bano or desh ko samalo")
# Out:
# padai likhai karo iaswias bano or desh ko samalo

# %%
num1=int(input("Enter your numbers"))
num2=int(input("Enter your numbers"))
num3=int(input("Enter your numbers"))
if num1<num2 and num1<num3:
    print(f"{num1} is the smallest number")
elif num2<num1 and num2<num3:
    print(f"{num2} is the smallest number")
else:  
     print(f"{num3} is the smallest number")
# Out:
# 1 is the smallest number
