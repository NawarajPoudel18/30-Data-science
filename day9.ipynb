# %%
with open("nawaraj.txt","r") as f:
    print(f.read())
# Out:
# hello this is test file

# %%
file = open("customers-100.csv","r")
lines= file.readlines()
for line in lines:
    print(line.strip())
file.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 # file = open("customers-100.csv","r")
# ----> 2 lines= file.readlines()
#       3 for line in lines:
#       4     print(line.strip())
#       5 file.close()
#
# ValueError: I/O operation on closed file.

# %%
file = open("nawaraj.txt","r")
lines=file.readlines()
print("total line ", len(lines))
file.close()
# Out:
# total line  1
