# %% [markdown]
# # start of pandas

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 2.7 MB/s  0:00:04 eta 0:00:01
# ...

# %%
import pandas as pd
a=[12,34,523,45432,3454,3234,43]
nga=pd.Series(a)
print(nga)
# Out:
# 0       12
# 1       34
# 2      523
# 3    45432
# 4     3454
# 5     3234
# 6       43
# dtype: int64

# %%
data={
    "day1":390,
    "day2":240
}
nga=pd.Series(data)
print(nga)
# Out:
# day1    390
# day2    240
# dtype: int64

# %%
data={
    "Employee name":["Balen","Nawaraj","Raju","Sacchu","Nirajan"],
    "Salary":[20000,2000000,23456,23453,1111111111],
    "degsination":["Dev","Manager","mistri","don","manager"],
}
d=pd.DataFrame(data)
# print("this is the data printed after the data frame\n",d)
d.head()
# print("this is the data printed by indexing the thing\n",d.loc[1])
# print("this is the data printed by indexing the thing",d[1]) this is not useable it shows the error stuff
# Out:
#   Employee name      Salary degsination
# 0         Balen       20000         Dev
# 1       Nawaraj     2000000     Manager
# 2          Raju       23456      mistri
# 3        Sacchu       23453         don
# 4       Nirajan  1111111111     manager

# %%
d=pd.read_csv("customers-100.csv")
d.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda                   -1199    (496)978-3969x58947
# ...

# %%
d.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    str
#  2   First Name         100 non-null    str
#  3   Last Name          100 non-null    str
#  4   Company            100 non-null    str
#  5   City               100 non-null    str
#  6   Country            100 non-null    str
#  7   Phone 1            100 non-null    str
#  8   Phone 2            100 non-null    str
#  9   Email              100 non-null    str
#  10  Subscription Date  100 non-null    str
#  11  Website            100 non-null    str
# dtypes: int64(1), str(11)
# memory usage: 9.5 KB

# %%
d.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
d=pd.read_csv("Mobile_data.csv")
d.head()
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422        1690        1529.0         1819.0
# 1  Android         323        1803        1659.0         2489.0
# 2  Android         299        1803        1659.0         2489.0
# 3  Android         287        1803        1659.0         2489.0
# 4  Android        1047        1999           NaN            NaN
#
#    sellers_amount  screen_size  memory_size  battery_size release_date
# 0              36         5.00          8.0        2000.0       20-Oct
# ...

# %%
d.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   str
#  2   model_name      1224 non-null   str
#  3   os              1027 non-null   str
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   int64
#  6   lowest_price    964 non-null    float64
#  7   highest_price   964 non-null    float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1222 non-null   float64
#  10  memory_size     1112 non-null   float64
#  11  battery_size    1214 non-null   float64
#  12  release_date    1224 non-null   str
# dtypes: float64(5), int64(4), str(4)
# memory usage: 124.4 KB

# %%
d.drop(columns="Unnamed: 0")
d.head()
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422        1690        1529.0         1819.0
# 1  Android         323        1803        1659.0         2489.0
# 2  Android         299        1803        1659.0         2489.0
# 3  Android         287        1803        1659.0         2489.0
# 4  Android        1047        1999           NaN            NaN
#
#    sellers_amount  screen_size  memory_size  battery_size release_date
# 0              36         5.00          8.0        2000.0       20-Oct
# ...

# %%
# d.drop(columns="Unnamed: 0",inplace=True)
d.head()
# Out:
#   brand_name                                    model_name       os  \
# 0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)  Android
# 1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)  Android
# 2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)  Android
# 3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)  Android
# 4      Nokia                           1.3 1/16GB Charcoal  Android
#
#    popularity  best_price  lowest_price  highest_price  sellers_amount  \
# 0         422        1690        1529.0         1819.0              36
# 1         323        1803        1659.0         2489.0              36
# 2         299        1803        1659.0         2489.0              36
# 3         287        1803        1659.0         2489.0              36
# 4        1047        1999           NaN            NaN              10
#
#    screen_size  memory_size  battery_size release_date
# 0         5.00          8.0        2000.0       20-Oct
# ...

# %%
d["brand_name"].unique()
# Out:
# <StringArray>
# [     'ALCATEL',        'Nokia',        'Honor',        'Meizu',
#        'realme',      'OnePlus',       'Archos',      'Ulefone',
#           'AGM',         'OPPO',        'Astro',       'Rezone',
#     'Blackview',       'Bravis',          'NUU',       'Lenovo',
#       'UMIDIGI',    'Assistant',    'Crosscall',        'Sharp',
#          'ERGO',        'Tecno',          'CAT',       'DOOGEE',
#        'Xiaomi',          'ZTE',      'Oukitel',        'Cubot',
#        'S-TELL', 'Sigma mobile',      'Coolpad',       'Bluboo',
#            'LG',     'Motorola',      'Philips',           '2E',
#           'Fly',      'Samsung',    'Prestigio',      'myPhone',
#    'BlackBerry',      'KENEKSI',       'Maxcom',       'HUAWEI',
#        'Vernee',      'General',       'Globex',      'Smartex',
#        'Google',         'ASUS',         'Land',        'MAFAM',
#         'Jinga',     'Vodafone',    'Microsoft',     'iOutdoor',
# ...

# %%
d["os"].unique() #shows unique value
# Out:
# <StringArray>
# ['Android', nan, 'iOS', 'OxygenOS', 'WindowsPhone', 'EMUI', 'KAIOS']
# Length: 7, dtype: str

# %%
d["os"].nunique()   # number of unique values
# Out:
# 6

# %%
d["os"].value_counts()   # count each unique value
# Out:
# os
# Android         915
# iOS             103
# OxygenOS          3
# WindowsPhone      3
# EMUI              2
# KAIOS             1
# Name: count, dtype: int64

# %%
d.loc[d["brand_name"]=="vivo"] #it help us to search the data according to the name
# Out:
#      brand_name                    model_name       os  popularity  \
# 932        vivo     V20 8/128GB Midnight Jazz  Android         894
# 933        vivo     V20 8/128GB Sunset Melody  Android         935
# 934        vivo  V20 SE 8/128GB Gravity Black  Android         684
# 1008       vivo        X50 8/128GB Frost Blue  Android         829
# 1009       vivo       X50 8/128GB Graze Black  Android         892
# 1012       vivo    X50 Pro 8/256GB Alpha Grey  Android         981
# 1054       vivo          Y11 3/32GB Agate Red  Android         388
# 1055       vivo          Y15 4/64GB Aqua Blue  Android         627
# 1056       vivo          Y15 4/64GB Aqua Blue  Android         623
# 1057       vivo       Y15 4/64GB Burgundy Red  Android         573
# 1058       vivo             Y19 4/128GB Black  Android         739
# 1059       vivo              Y1S 2/32GB Black  Android         680
# 1060       vivo               Y1S 2/32GB Blue  Android         574
# ...

# %%
d["os"].shape            # size of column
# Out:
# (1224,)
