# %%
n=input("Enter your name")
print(f"Hello {n}, Welcome to system")
# Out:
# Hello nawaraj, Welcome to system

# %%
def hello(n):
    print(f"Hello {n}, Welcome to system")
hello("akarsh")
# Out:
# Hello akarsh, Welcome to system

# %%
def hello(n):
    return f"Hello {n}, Welcome to system"
print(hello("akarsh"))

# %%
def hello(price,discount):
    if(discount<0 or discount>100):
        return "Invalid discount"
    return price*(discount/100)
print(hello(200,10.5))
# Out:
# 21.0

# %% [markdown]
# Temprature

# %%
def c_to_f(c):
    return c*1.8+32
def f_to_c(f):
    return (f-32)/1.8
print(c_to_f(32))
print(f_to_c(89.6))
# Out:
# 89.6
# 31.999999999999996
