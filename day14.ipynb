# %%
import pandas as pd
d=pd.read_csv("Mobile_data.csv")

# %%
d.isnull().sum
# Out:
# <bound method DataFrame.sum of       Unnamed: 0  brand_name  model_name     os  popularity  best_price  \
# 0          False       False       False  False       False       False
# 1          False       False       False  False       False       False
# 2          False       False       False  False       False       False
# 3          False       False       False  False       False       False
# 4          False       False       False  False       False       False
# ...          ...         ...         ...    ...         ...         ...
# 1219       False       False       False  False       False       False
# 1220       False       False       False  False       False       False
# 1221       False       False       False  False       False       False
# 1222       False       False       False  False       False       False
# 1223       False       False       False   True       False       False
#
# ...

# %%
d.duplicated().sum
# Out:
# <bound method Series.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1219    False
# 1220    False
# 1221    False
# 1222    False
# 1223    False
# Length: 1224, dtype: bool>

# %%
d.drop_duplicates()
# Out:
#       Unnamed: 0    brand_name                                    model_name  \
# 0              0       ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1              1       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2              2       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3              3       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4              4         Nokia                           1.3 1/16GB Charcoal
# ...          ...           ...                                           ...
# 1219        1219         Apple               iPhone XS Max 64GB Gold (MT522)
# 1220        1220         Apple      iPhone XS Max Dual Sim 64GB Gold (MT732)
# 1221        1221        HUAWEI              nova 5T 6/128GB Black (51094MEU)
# 1222        1222           ZTE              nubia Red Magic 5G 8/128GB Black
# 1223        1223  Sigma mobile                             x-style 35 Screen
#
# ...

# %%
n=d.fillna(100)
n.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   str
#  2   model_name      1224 non-null   str
#  3   os              1224 non-null   object
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   int64
#  6   lowest_price    1224 non-null   float64
#  7   highest_price   1224 non-null   float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1224 non-null   float64
#  10  memory_size     1224 non-null   float64
#  11  battery_size    1224 non-null   float64
#  12  release_date    1224 non-null   str
# dtypes: float64(5), int64(4), object(1), str(3)
# memory usage: 124.4+ KB

# %%
n.head()
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422        1690        1529.0         1819.0
# 1  Android         323        1803        1659.0         2489.0
# 2  Android         299        1803        1659.0         2489.0
# 3  Android         287        1803        1659.0         2489.0
# 4  Android        1047        1999         100.0          100.0
#
#    sellers_amount  screen_size  memory_size  battery_size release_date
# 0              36         5.00          8.0        2000.0       20-Oct
# ...

# %%
# x=d['highest_price'].mean()
# print(x)

# %%
# x=d['highest_price'].mean()
# n=d.fillna(x)
# n.head(10)

# %%
# d['highest_price']=d['highest_price'].mean()
d.head(10)
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
# 5           5      Honor                               10 6/64GB Black
# 6           6      Honor                           10 Lite 3/32GB Blue
# 7           7      Honor                          10 Lite 4/64GB Black
# 8           8      Honor                          10 lite 3/128GB Blue
# 9           9      Honor                          10 lite 3/64GB Black
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422        1690        1529.0         1819.0
# ...

# %%
d['lowest_price']=d['lowest_price'].fillna(d.groupby('brand_name')['lowest_price'].transform('mean'))
d.head(10)
# x=d['lowest_price'].mean()
# print(x)
# d.info()
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
# 5           5      Honor                               10 6/64GB Black
# 6           6      Honor                           10 Lite 3/32GB Blue
# 7           7      Honor                          10 Lite 4/64GB Black
# 8           8      Honor                          10 lite 3/128GB Blue
# 9           9      Honor                          10 lite 3/64GB Black
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422        1690   1529.000000         1819.0
# ...

# %%
d['lowest_price']=d['lowest_price'].mean()
d.head()
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422        1690   7631.446981         1819.0
# 1  Android         323        1803   7631.446981         2489.0
# 2  Android         299        1803   7631.446981         2489.0
# 3  Android         287        1803   7631.446981         2489.0
# 4  Android        1047        1999   7631.446981            NaN
#
#    sellers_amount  screen_size  memory_size  battery_size release_date
# 0              36         5.00          8.0        2000.0       20-Oct
# ...

# %%
d.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   str
#  2   model_name      1224 non-null   str
#  3   os              1027 non-null   str
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   int64
#  6   lowest_price    1224 non-null   float64
#  7   highest_price   964 non-null    float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1222 non-null   float64
#  10  memory_size     1112 non-null   float64
#  11  battery_size    1214 non-null   float64
#  12  release_date    1224 non-null   str
# dtypes: float64(5), int64(4), str(4)
# memory usage: 124.4 KB

# %%
d=d.dropna(subset=['os'])
d.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1027 entries, 0 to 1222
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1027 non-null   int64
#  1   brand_name      1027 non-null   str
#  2   model_name      1027 non-null   str
#  3   os              1027 non-null   str
#  4   popularity      1027 non-null   int64
#  5   best_price      1027 non-null   int64
#  6   lowest_price    1027 non-null   float64
#  7   highest_price   791 non-null    float64
#  8   sellers_amount  1027 non-null   int64
#  9   screen_size     1026 non-null   float64
#  10  memory_size     1027 non-null   float64
#  11  battery_size    1017 non-null   float64
#  12  release_date    1027 non-null   str
# dtypes: float64(5), int64(4), str(4)
# memory usage: 112.3 KB

# %%
d=d.dropna(subset=['battery_size'])
d.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1017 entries, 0 to 1222
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1017 non-null   int64
#  1   brand_name      1017 non-null   str
#  2   model_name      1017 non-null   str
#  3   os              1017 non-null   str
#  4   popularity      1017 non-null   int64
#  5   best_price      1017 non-null   int64
#  6   lowest_price    1017 non-null   float64
#  7   highest_price   781 non-null    float64
#  8   sellers_amount  1017 non-null   int64
#  9   screen_size     1016 non-null   float64
#  10  memory_size     1017 non-null   float64
#  11  battery_size    1017 non-null   float64
#  12  release_date    1017 non-null   str
# dtypes: float64(5), int64(4), str(4)
# memory usage: 111.2 KB

# %%
d=d.dropna(subset=['screen_size'])
d.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1016 entries, 0 to 1222
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1016 non-null   int64
#  1   brand_name      1016 non-null   str
#  2   model_name      1016 non-null   str
#  3   os              1016 non-null   str
#  4   popularity      1016 non-null   int64
#  5   best_price      1016 non-null   int64
#  6   lowest_price    1016 non-null   float64
#  7   highest_price   780 non-null    float64
#  8   sellers_amount  1016 non-null   int64
#  9   screen_size     1016 non-null   float64
#  10  memory_size     1016 non-null   float64
#  11  battery_size    1016 non-null   float64
#  12  release_date    1016 non-null   str
# dtypes: float64(5), int64(4), str(4)
# memory usage: 111.1 KB

# %%
d['release_date']=pd.to_datetime(d['release_date'])
d.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1016 entries, 0 to 1222
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1016 non-null   int64
#  1   brand_name      1016 non-null   str
#  2   model_name      1016 non-null   str
#  3   os              1016 non-null   str
#  4   popularity      1016 non-null   int64
#  5   best_price      1016 non-null   int64
#  6   lowest_price    1016 non-null   float64
#  7   highest_price   780 non-null    float64
#  8   sellers_amount  1016 non-null   int64
#  9   screen_size     1016 non-null   float64
#  10  memory_size     1016 non-null   float64
#  11  battery_size    1016 non-null   float64
#  12  release_date    1016 non-null   datetime64[us]
# dtypes: datetime64[us](1), float64(5), int64(4), str(3)
# memory usage: 111.1 KB
# ...

# %%
d=d.rename(columns={'release_date':'date'})
# d.info()
d.head()
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422        1690   7631.446981         1819.0
# 1  Android         323        1803   7631.446981         2489.0
# 2  Android         299        1803   7631.446981         2489.0
# 3  Android         287        1803   7631.446981         2489.0
# 4  Android        1047        1999   7631.446981            NaN
#
#    sellers_amount  screen_size  memory_size  battery_size    date
# 0              36         5.00          8.0        2000.0 1-10-20
# ...
